# %% [markdown]
# <a href="https://colab.research.google.com/github/TamaradosAnjos/Pesquisa_Kaggle_ML_-_Data_Science_2022/blob/main/Pesquisa_Kaggle_Machine_Learning_%26_Data_Science_2022.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import pyplot as plt

# %%
df = pd.read_csv('/content/drive/MyDrive/Dados kaggle/kaggle_survey_2022_responses.csv', sep = ",")
df
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (0,208,225,255,257,260,270,271,277) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#        Duration (in seconds)                           Q2  \
# 0      Duration (in seconds)  What is your age (# years)?
# 1                        121                        30-34
# 2                        462                        30-34
# 3                        293                        18-21
# 4                        851                        55-59
# ...                      ...                          ...
# 23993                    331                        22-24
# 23994                    330                        60-69
# 23995                    860                        25-29
# 23996                    597                        35-39
# 23997                    303                        18-21
#
# ...

# %%
column_names = list(df.columns)
column_names
# Out:
# ['Duration (in seconds)',
#  'Q2',
#  'Q3',
#  'Q4',
#  'Q5',
#  'Q6_1',
#  'Q6_2',
#  'Q6_3',
#  'Q6_4',
#  'Q6_5',
#  'Q6_6',
#  'Q6_7',
#  'Q6_8',
#  'Q6_9',
#  'Q6_10',
#  'Q6_11',
#  'Q6_12',
#  'Q7_1',
#  'Q7_2',
#  'Q7_3',
#  'Q7_4',
#  'Q7_5',
#  'Q7_6',
#  'Q7_7',
#  'Q8',
#  'Q9',
#  'Q10_1',
#  'Q10_2',
#  'Q10_3',
#  'Q11',
#  'Q12_1',
#  'Q12_2',
#  'Q12_3',
#  'Q12_4',
#  'Q12_5',
#  'Q12_6',
#  'Q12_7',
#  'Q12_8',
#  'Q12_9',
#  'Q12_10',
#  'Q12_11',
#  'Q12_12',
#  'Q12_13',
#  'Q12_14',
#  'Q12_15',
#  'Q13_1',
#  'Q13_2',
#  'Q13_3',
#  'Q13_4',
#  'Q13_5',
#  'Q13_6',
#  'Q13_7',
#  'Q13_8',
#  'Q13_9',
#  'Q13_10',
#  'Q13_11',
#  'Q13_12',
#  'Q13_13',
#  'Q13_14',
#  'Q14_1',
#  'Q14_2',
#  'Q14_3',
#  'Q14_4',
#  'Q14_5',
#  'Q14_6',
#  'Q14_7',
#  'Q14_8',
#  'Q14_9',
#  'Q14_10',
#  'Q14_11',
#  'Q14_12',
#  'Q14_13',
#  'Q14_14',
#  'Q14_15',
#  'Q14_16',
#  'Q15_1',
#  'Q15_2',
#  'Q15_3',
#  'Q15_4',
#  'Q15_5',
#  'Q15_6',
#  'Q15_7',
#  'Q15_8',
# ...

# %%
#Saber quantos valores tem item da coluna
Country_sum = df.pivot_table(columns=['Q4'], aggfunc='size')
print (Country_sum)
# Out:
# Q4
# Algeria                                                   62
# Argentina                                                204
# Australia                                                142
# Bangladesh                                               251
# Belgium                                                   51
# Brazil                                                   833
# Cameroon                                                  68
# Canada                                                   257
# Chile                                                    115
# China                                                    453
# Colombia                                                 256
# Czech Republic                                            49
# Ecuador                                                   54
# Egypt                                                    383
# Ethiopia                                                  98
# ...

# %%
df_BR=df.query("Q4 == 'Brazil'")
df_BR.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 833 entries, 26 to 23963
# Columns: 296 entries, Duration (in seconds) to Q44_12
# dtypes: object(296)
# memory usage: 1.9+ MB

# %%
df_IN=df.query("Q4 == 'India'")
df_IN.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8792 entries, 1 to 23997
# Columns: 296 entries, Duration (in seconds) to Q44_12
# dtypes: object(296)
# memory usage: 19.9+ MB

# %%
df_USA=df.query("Q4 == 'United States of America'")
df_USA.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2920 entries, 14 to 23994
# Columns: 296 entries, Duration (in seconds) to Q44_12
# dtypes: object(296)
# memory usage: 6.6+ MB

# %%
df_BR=df_BR.groupby(['Q2','Q4']).size()
df_BR=df_BR.unstack()
df_BR.plot(kind='bar')

# %%
#countrys=['Brazil','India']
#df.query("Q4 in @countrys")

# %%
# By using lambda function. Caso eu quisesse usar 3 paises. 
#df_country = print(df.apply(lambda row: row[df['Q4'].isin(['Brazil','India','United States of America'])]))
